# %%
import pandas as pd

df = pd.read_csv(
    "tablas/ajustes_inventario_registro.csv"
)

if "Día" not in df.columns:
    df.insert(1, "Día", "")

if "Mes" not in df.columns:
    df.insert(2, "Mes", "")

if "Año" not in df.columns:
    df.insert(3, "Año", "")

df.to_csv(
    "tablas/ajustes_inventario_registro.csv",
    index=False
)

print("Columnas agregadas correctamente.")
print(df.columns.tolist())
# Out:
# Columnas agregadas correctamente.
# ['Fecha', 'Día', 'Mes', 'Año', 'Accion', 'Desc.1', 'Desc.2', 'Talla', 'cantidad', 'Motivo', 'INVENTARIO', 'Val. Unitario', 'Subtotal']

# %%
import pandas as pd

df = pd.read_csv(
    "tablas/ajustes_inventario_registro.csv"
)

print(df.columns.tolist())
print()
print(df.head())
# Out:
# ['Fecha;Día;Mes;Año;Accion;Desc.1;Desc.2;Talla;cantidad;Motivo;INVENTARIO;Val. Unitario;Subtotal']
#
#   Fecha;Día;Mes;Año;Accion;Desc.1;Desc.2;Talla;cantidad;Motivo;INVENTARIO;Val. Unitario;Subtotal
# 0  08/05/2026;;;;SALIDA MERCANCIA;conalco;camiset...
# 1  11/05/2026;;;;INGRESO MERCANCIA;conalco;bombac...
# 2  11/05/2026;;;;SALIDA MERCANCIA;conalco;bombach...
# 3  12/05/2026;;;;INGRESO MERCANCIA;conalco;pantal...
# 4  12/05/2026;;;;SALIDA MERCANCIA;conalco;pantalo...

# %%
import pandas as pd

df = pd.read_csv(
    "tablas/ajustes_inventario_registro.csv",
    sep=";"
)

print(df.columns.tolist())
# Out:
# ['Fecha', 'Día', 'Mes', 'Año', 'Accion', 'Desc.1', 'Desc.2', 'Talla', 'cantidad', 'Motivo', 'INVENTARIO', 'Val. Unitario', 'Subtotal']

# %%
import pandas as pd

df = pd.read_csv(
    "tablas/ajustes_inventario_registro.csv",
    sep=";"
)

df.tail(5)
# Out:
#          Fecha  Día  Mes  Año             Accion              Desc.1  \
# 80  09/06/2026  NaN  NaN  NaN   SALIDA MERCANCIA             conalco
# 81  10/06/2026  NaN  NaN  NaN  INGRESO MERCANCIA             colsafa
# 82  10/06/2026  NaN  NaN  NaN   SALIDA MERCANCIA             colsafa
# 83         NaN  NaN  NaN  NaN            INGRESA  liceo pupo jimenez
# 84         NaN  NaN  NaN  NaN               SALE  liceo pupo jimenez
#
#        Desc.2 Talla  cantidad           Motivo  INVENTARIO  Val. Unitario  \
# 80   bombacho     L         1  CAMBIO DE TALLA        -1.0        69000.0
# 81  guayabera     S         1  CAMBIO DE TALLA         1.0        59000.0
# 82  guayabera     M         1  CAMBIO DE TALLA        -1.0        59000.0
# 83      blusa     2         1  CAMBIO DE TALLA         NaN        37000.0
# 84      blusa     4         1  CAMBIO DE TALLA         NaN        37000.0
#
#     Subtotal
# 80  -69000.0
# 81   59000.0
# 82  -59000.0
# 83   37000.0
# 84   37000.0

# %%
import pandas as pd

df = pd.read_csv(
    "tablas/ajustes_inventario_registro.csv",
    sep=";"
)

for i, col in enumerate(df.columns):
    print(i, repr(col))
# Out:
# 0 'Fecha'
# 1 'Día'
# 2 'Mes'
# 3 'Año'
# 4 'Accion'
# 5 'Desc.1'
# 6 'Desc.2'
# 7 'Talla'
# 8 'cantidad'
# 9 'Motivo'
# 10 'INVENTARIO'
# 11 'Val. Unitario'
# 12 'Subtotal'
