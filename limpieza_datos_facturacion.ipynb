# %%
import pandas as pd
from datetime import datetime

# %%
import pandas as pd

# Cargar archivo
df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";"
)

# Columnas a eliminar
columnas_eliminar = [
    "Unnamed: 27",
    "Unnamed: 28",
    "Aux busqueda fecha",
    "calculo valor factura",
    "conteo"
]

# Eliminar solo si existen
df = df.drop(
    columns=[
        col
        for col in columnas_eliminar
        if col in df.columns
    ],
    errors="ignore"
)

# Guardar nuevamente
df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("✅ Limpieza completada")
print(f"Columnas restantes: {len(df.columns)}")
# Out:
# /tmp/ipykernel_8015/1846788727.py:4: DtypeWarning: Columns (0: Nombre cliente, 1: total tarjeta, 2: Hora) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# ✅ Limpieza completada
# Columnas restantes: 28

# %%
#Fecha

import pandas as pd

df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";"
)

dias_semana = [
    "lunes",
    "martes",
    "miércoles",
    "jueves",
    "viernes",
    "sábado",
    "domingo"
]

meses = [
    "",
    "enero",
    "febrero",
    "marzo",
    "abril",
    "mayo",
    "junio",
    "julio",
    "agosto",
    "septiembre",
    "octubre",
    "noviembre",
    "diciembre"
]

def fecha_bonita(fecha):
    fecha = pd.to_datetime(
        fecha,
        dayfirst=True
    )

    return (
        f"{dias_semana[fecha.weekday()]}, "
        f"{fecha.day} de "
        f"{meses[fecha.month]} de "
        f"{fecha.year}"
    )

df["fecha de venta"] = (
    df["fecha de venta"]
    .apply(fecha_bonita)
)

df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("Fechas convertidas.")
# Out:
# /tmp/ipykernel_8015/3039039079.py:5: DtypeWarning: Columns (0: Nombre cliente, 1: total tarjeta, 2: Hora) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[5], line 51
#      47     )
#      48
#      49 df["fecha de venta"] = (
#      50     df["fecha de venta"]
# ---> 51     .apply(fecha_bonita)
#      52 )
#      53
#      54 df.to_csv(
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py:1753, in ArrowExtensionArray.map(self, mapper, na_action)
#    1747     return map_array(self.to_numpy(), mapper, na_action=na_action)
#    1748 else:
#    1749     # For "mM" cases, the super() method passes `self` without the
#    1750     #  to_numpy call, which inside map_array casts to ndarray[object].
#    1751     #  Without the to_numpy() call, NA is preserved instead of changed
#    1752     #  to None.
# -> 1753     return super().map(mapper, na_action)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/arrays/base.py:2745, in ExtensionArray.map(self, mapper, na_action)
#    2725 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2726     """
#    2727     Map values using an input mapping or function.
#    2728
#    (...)   2743         a MultiIndex will be returned.
#    2744     """
# -> 2745     return map_array(self, mapper, na_action=na_action)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/algorithms.py:1715, in map_array(arr, mapper, na_action)
#    1713 values = arr.astype(object, copy=False)
#    1714 if na_action is None:
# -> 1715     return lib.map_infer(values, mapper)
#    1716 else:
#    1717     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
# -> 3071 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[5], line 37, in fecha_bonita(fecha)
#      36 def fecha_bonita(fecha):
# ---> 37     fecha = pd.to_datetime(
#      38         fecha,
#      39         dayfirst=True
#      40     )
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1074, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1072         result = convert_listlike(argc, format)
#    1073 else:
# -> 1074     result = convert_listlike(np.array([arg]), format)[0]
#    1075     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1076         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/arrays/datetimes.py:2623, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2620 # if str-dtype, convert
#    2621 data = np.asarray(data, dtype=np.object_)
# -> 2623 result, tz_parsed = tslib.array_to_datetime(
#    2624     data,
#    2625     errors=errors,
#    2626     utc=utc,
#    2627     dayfirst=dayfirst,
#    2628     yearfirst=yearfirst,
#    2629     creso=abbrev_to_npy_unit(out_unit),
#    2630 )
#    2632 if tz_parsed is not None:
#    2633     # We can take a shortcut since the datetime64 numpy array
#    2634     #  is in UTC
#    2635     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:259, in pandas._libs.tslib.array_to_datetime()
# --> 259 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslib.pyx:473, in pandas._libs.tslib.array_to_datetime()
# --> 473 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslib.pyx:430, in pandas._libs.tslib.array_to_datetime()
# --> 430 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/conversion.pyx:658, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
# --> 658 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:321, in pandas._libs.tslibs.parsing.parse_datetime_string()
# --> 321 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:652, in pandas._libs.tslibs.parsing.dateutil_parse()
# --> 652 'Could not get source, probably due dynamically evaluated source code.'
#
# DateParseError: Unknown datetime string format, unable to parse: jueves, 11 de junio de 2026

# %%
# posicion de la columna hora
import pandas as pd

# ----------------------------
# ventas_df
# ----------------------------

df = pd.read_csv(
    "tablas/ventas_df.csv",
    sep=";",
    low_memory=False
)

columnas = list(df.columns)

columnas.remove("hora")

columnas.insert(
    2,
    "hora"
)

df = df[columnas]

df.to_csv(
    "tablas/ventas_df.csv",
    sep=";",
    index=False
)

print("ventas_df actualizado")

# ----------------------------
# facturacion_ventas
# ----------------------------

df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    low_memory=False
)

columnas = list(df.columns)

columnas.remove("Hora")

columnas.insert(
    2,
    "Hora"
)

df = df[columnas]

df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("facturacion_ventas actualizado")

print("Proceso terminado")
# Out:
# ventas_df actualizado
# facturacion_ventas actualizado
# Proceso terminado
