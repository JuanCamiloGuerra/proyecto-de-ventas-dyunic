# %%
import pandas as pd
from datetime import datetime

# %%
import pandas as pd

# Cargar archivo
df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";"
)

# Columnas a eliminar
columnas_eliminar = [
    "Unnamed: 27",
    "Unnamed: 28",
    "Aux busqueda fecha",
    "calculo valor factura",
    "conteo"
]

# Eliminar solo si existen
df = df.drop(
    columns=[
        col
        for col in columnas_eliminar
        if col in df.columns
    ],
    errors="ignore"
)

# Guardar nuevamente
df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("✅ Limpieza completada")
print(f"Columnas restantes: {len(df.columns)}")
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_8768\1846788727.py:4: DtypeWarning: Columns (5,6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# ✅ Limpieza completada
# Columnas restantes: 27

# %%
#Fecha

import pandas as pd

df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";"
)

dias_semana = [
    "lunes",
    "martes",
    "miércoles",
    "jueves",
    "viernes",
    "sábado",
    "domingo"
]

meses = [
    "",
    "enero",
    "febrero",
    "marzo",
    "abril",
    "mayo",
    "junio",
    "julio",
    "agosto",
    "septiembre",
    "octubre",
    "noviembre",
    "diciembre"
]

def fecha_bonita(fecha):
    fecha = pd.to_datetime(
        fecha,
        dayfirst=True
    )

    return (
        f"{dias_semana[fecha.weekday()]}, "
        f"{fecha.day} de "
        f"{meses[fecha.month]} de "
        f"{fecha.year}"
    )

df["fecha de venta"] = (
    df["fecha de venta"]
    .apply(fecha_bonita)
)

df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("Fechas convertidas.")
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_8768\3039039079.py:5: DtypeWarning: Columns (5,6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Fechas convertidas.

# %%
# posicion de la columna hora
import pandas as pd

# ----------------------------
# ventas_df
# ----------------------------

df = pd.read_csv(
    "tablas/ventas_df.csv",
    sep=";",
    low_memory=False
)

columnas = list(df.columns)

columnas.remove("hora")

columnas.insert(
    2,
    "hora"
)

df = df[columnas]

df.to_csv(
    "tablas/ventas_df.csv",
    sep=";",
    index=False
)

print("ventas_df actualizado")

# ----------------------------
# facturacion_ventas
# ----------------------------

df = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    low_memory=False
)

columnas = list(df.columns)

columnas.remove("Hora")

columnas.insert(
    2,
    "Hora"
)

df = df[columnas]

df.to_csv(
    "tablas/facturacion_ventas.csv",
    sep=";",
    index=False
)

print("facturacion_ventas actualizado")

print("Proceso terminado")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#       8 df = pd.read_csv(
#       9     "tablas/ventas_df.csv",
#      10     sep=";",
#      11     low_memory=False
#      12 )
#      14 columnas = list(df.columns)
# ---> 16 columnas.remove("hora")
#      18 columnas.insert(
#      19     2,
#      20     "hora"
#      21 )
#      23 df = df[columnas]
#
# ValueError: list.remove(x): x not in list
