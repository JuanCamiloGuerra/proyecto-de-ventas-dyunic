# %%
import pandas as pd
from datetime import datetime

# %%
df_facturas = pd.read_csv(
    "tablas/facturacion_ventas.csv",
    sep=";"
)
# Out:
# /tmp/ipykernel_12153/3361808365.py:1: DtypeWarning: Columns (0: Nombre cliente, 1: total tarjeta, 2: Unnamed: 27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_facturas = pd.read_csv(

# %%
print(df_facturas.columns)
# Out:
# Index(['ID unico de factura', 'fecha de venta', 'Día', 'Mes', 'Año',
#        'Nombre cliente', 'Numero de contacto', 'ID cliente', 'pago efectivo',
#        'pago tarjeta', 'pago transferencia', 'total pagado 1', 'valor factura',
#        'pendiente', 'fecha de pago 2', 'pago efectivo 2', 'pago tarjeta 2',
#        'pago transferencia 2', 'Estado de factura', 'total efectivo',
#        'total tarjeta', ' total transfencia ', 'total pendiente',
#        ' Producto pendiente por entregar ', 'calculo valor factura conteo',
#        'Lista rapida', 'Aux busqueda fehca', 'Unnamed: 27', 'Unnamed: 28'],
#       dtype='str')
