# %%
import datetime
import random
import altair as alt
import numpy as np
import pandas as pd
import streamlit as st

# %%
df2 = pd.read_csv("ventas_df.csv", sep=";")
# Out:
# /tmp/ipykernel_14967/363889082.py:1: DtypeWarning: Columns (0: Unnamed: 2, 1: Unnamed: 3, 2: Unnamed: 4, 3: Unnamed: 8, 4: Unnamed: 9, 5: Unnamed: 10, 6: Unnamed: 11, 7: Unnamed: 13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("ventas_df.csv", sep=";")

# %%
df2
# Out:
#                                               Unnamed: 0  \
# 0                                                    NaN
# 1                                    ID unico de factura
# 2            NA FACTURA-44572-liceo pupo jimenez_falda_8
# 3      NA FACTURA-44572-liceo pupo jimenez_camiseta f...
# 4         NA FACTURA-44572-liceo pupo jimenez_bombacho_6
# ...                                                  ...
# 45934                                   BGT_CLE_46175---
# 45935                                   BGT_CLE_46175---
# 45936                                   BGT_CLE_46175---
# 45937                                   BGT_CLE_46176---
# 45938                                   BGT_CLE_46176---
#
#                           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                NaN        NaN        NaN        NaN
# 1                              fecha        dia        mes        año
# 2        martes, 11 de enero de 2022         11          1       2022
# 3        martes, 11 de enero de 2022         11          1       2022
# 4        martes, 11 de enero de 2022         11          1       2022
# ...                              ...        ...        ...        ...
# 45934     martes, 2 de junio de 2026          2          6       2026
# 45935     martes, 2 de junio de 2026          2          6       2026
# 45936     martes, 2 de junio de 2026          2          6       2026
# 45937  miércoles, 3 de junio de 2026          3          6       2026
# 45938  miércoles, 3 de junio de 2026          3          6       2026
#
#                  Unnamed: 5                  Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                       NaN                         NaN        NaN        NaN
# 1                   colegio                    articulo      talla     hombro
# 2        liceo pupo jimenez                       falda          8        NaN
# 3        liceo pupo jimenez             camiseta fisica          8        NaN
# 4        liceo pupo jimenez                    bombacho          6        NaN
# ...                     ...                         ...        ...        ...
# 45934        Antonio Narino      Camiseta diario/fisica         10        NaN
# 45935         la inmaculada                    bombacho         10        NaN
# 45936         la inmaculada             camiseta fisica         10        NaN
# 45937  gimnasio vallegrande  camiseta de fisica externa          M        NaN
# 45938  gimnasio vallegrande          camiseta de diario          S        NaN
#
#       Unnamed: 9  ... Unnamed: 11  \
# 0            NaN  ...         NaN
# 1          talle  ...       largo
# 2            NaN  ...         NaN
# 3            NaN  ...         NaN
# 4            NaN  ...         NaN
# ...          ...  ...         ...
# 45934        NaN  ...         NaN
# 45935        NaN  ...         NaN
# 45936        NaN  ...         NaN
# 45937        NaN  ...         NaN
# 45938        NaN  ...         NaN
#
#                                              Unnamed: 12 Unnamed: 13  \
# 0                                                    NaN         NaN
# 1                                   ID unico de artículo   cantidad
# 2                             liceo pupo jimenez_falda_8           1
# 3                   liceo pupo jimenez_camiseta fisica_8           1
# 4                          liceo pupo jimenez_bombacho_6           1
# ...                                                  ...         ...
# 45934           Antonio Narino_Camiseta diario/fisica_10           2
# 45935                          la inmaculada_bombacho_10           1
# 45936                   la inmaculada_camiseta fisica_10           1
# 45937  gimnasio vallegrande_camiseta de fisica externa_M           1
# 45938          gimnasio vallegrande_camiseta de diario_S           1
#
#                Unnamed: 14 Unnamed: 15         Unnamed: 16  \
# 0                      NaN         NaN                 NaN
# 1       precio individual    subtotal      Estado Factura
# 2                  70.000      70.000    PAGADA / CERRADA
# 3                  31.000      31.000    PAGADA / CERRADA
# 4                  34.000      34.000    PAGADA / CERRADA
# ...                    ...         ...                 ...
# 45934              45.000      90.000    PAGADA / CERRADA
# 45935              58.000      58.000    PAGADA / CERRADA
# 45936              41.000      41.000    PAGADA / CERRADA
# 45937              53.000      53.000    PAGADA / CERRADA
# 45938              59.000      59.000    PAGADA / CERRADA
#
#                              Unnamed: 17              Unnamed: 18  \
# 0                                    NaN                      NaN
# 1       Producto pendiente por entregar    Clasificación_antiguo
# 2                                    NO                     VENTA
# 3                                    NO                     VENTA
# 4                                    NO                     VENTA
# ...                                  ...                      ...
# 45934                                NO                     VENTA
# 45935                                NO                     VENTA
# 45936                                NO                     VENTA
# 45937                                NO                     VENTA
# 45938                                NO                     VENTA
#
#                     Unnamed: 19 Unnamed: 20
# 0                           NaN         NaN
# 1       Método de pago_antiguo       Nombre
# 2                            ef         NA
# 3                            ef         NA
# 4                            ef         NA
# ...                         ...         ...
# 45934                       NaN        -
# 45935                       NaN        -
# 45936                       NaN        -
# 45937                       NaN        -
# 45938                       NaN        -
#
# [45939 rows x 21 columns]

# %%
df=df2.copy()
    # La fila 1 contiene los nombres reales
df.columns = df.iloc[1]

    # Eliminar fila vacía y fila de encabezados
df = df.iloc[2:].reset_index(drop=True)

st.session_state.df = df
# Out:
# 2026-06-03 16:13:28.408 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-03 16:13:28.410 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-06-03 16:13:28.410 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df
# Out:
# 1                                    ID unico de factura  \
# 0            NA FACTURA-44572-liceo pupo jimenez_falda_8
# 1      NA FACTURA-44572-liceo pupo jimenez_camiseta f...
# 2         NA FACTURA-44572-liceo pupo jimenez_bombacho_6
# 3            NA FACTURA-44572-liceo pupo jimenez_falda_6
# 4            NA FACTURA-44572-liceo pupo jimenez_blusa_6
# ...                                                  ...
# 45932                                   BGT_CLE_46175---
# 45933                                   BGT_CLE_46175---
# 45934                                   BGT_CLE_46175---
# 45935                                   BGT_CLE_46176---
# 45936                                   BGT_CLE_46176---
#
# 1                              fecha dia mes   año               colegio  \
# 0        martes, 11 de enero de 2022  11   1  2022    liceo pupo jimenez
# 1        martes, 11 de enero de 2022  11   1  2022    liceo pupo jimenez
# 2        martes, 11 de enero de 2022  11   1  2022    liceo pupo jimenez
# 3        martes, 11 de enero de 2022  11   1  2022    liceo pupo jimenez
# 4        martes, 11 de enero de 2022  11   1  2022    liceo pupo jimenez
# ...                              ...  ..  ..   ...                   ...
# 45932     martes, 2 de junio de 2026   2   6  2026        Antonio Narino
# 45933     martes, 2 de junio de 2026   2   6  2026         la inmaculada
# 45934     martes, 2 de junio de 2026   2   6  2026         la inmaculada
# 45935  miércoles, 3 de junio de 2026   3   6  2026  gimnasio vallegrande
# 45936  miércoles, 3 de junio de 2026   3   6  2026  gimnasio vallegrande
#
# 1                        articulo talla hombro talle  ... largo  \
# 0                           falda     8    NaN   NaN  ...   NaN
# 1                 camiseta fisica     8    NaN   NaN  ...   NaN
# 2                        bombacho     6    NaN   NaN  ...   NaN
# 3                           falda     6    NaN   NaN  ...   NaN
# 4                           blusa     6    NaN   NaN  ...   NaN
# ...                           ...   ...    ...   ...  ...   ...
# 45932      Camiseta diario/fisica    10    NaN   NaN  ...   NaN
# 45933                    bombacho    10    NaN   NaN  ...   NaN
# 45934             camiseta fisica    10    NaN   NaN  ...   NaN
# 45935  camiseta de fisica externa     M    NaN   NaN  ...   NaN
# 45936          camiseta de diario     S    NaN   NaN  ...   NaN
#
# 1                                   ID unico de artículo  cantidad   \
# 0                             liceo pupo jimenez_falda_8          1
# 1                   liceo pupo jimenez_camiseta fisica_8          1
# 2                          liceo pupo jimenez_bombacho_6          1
# 3                             liceo pupo jimenez_falda_6          1
# 4                             liceo pupo jimenez_blusa_6          2
# ...                                                  ...        ...
# 45932           Antonio Narino_Camiseta diario/fisica_10          2
# 45933                          la inmaculada_bombacho_10          1
# 45934                   la inmaculada_camiseta fisica_10          1
# 45935  gimnasio vallegrande_camiseta de fisica externa_M          1
# 45936          gimnasio vallegrande_camiseta de diario_S          1
#
# 1      precio individual   subtotal      Estado Factura   \
# 0                 70.000     70.000    PAGADA / CERRADA
# 1                 31.000     31.000    PAGADA / CERRADA
# 2                 34.000     34.000    PAGADA / CERRADA
# 3                 70.000     70.000    PAGADA / CERRADA
# 4                 27.000     54.000    PAGADA / CERRADA
# ...                   ...        ...                 ...
# 45932             45.000     90.000    PAGADA / CERRADA
# 45933             58.000     58.000    PAGADA / CERRADA
# 45934             41.000     41.000    PAGADA / CERRADA
# 45935             53.000     53.000    PAGADA / CERRADA
# 45936             59.000     59.000    PAGADA / CERRADA
#
# 1      Producto pendiente por entregar   Clasificación_antiguo   \
# 0                                   NO                    VENTA
# 1                                   NO                    VENTA
# 2                                   NO                    VENTA
# 3                                   NO                    VENTA
# 4                                   NO                    VENTA
# ...                                 ...                     ...
# 45932                               NO                    VENTA
# 45933                               NO                    VENTA
# 45934                               NO                    VENTA
# 45935                               NO                    VENTA
# 45936                               NO                    VENTA
#
# 1      Método de pago_antiguo  Nombre
# 0                           ef    NA
# 1                           ef    NA
# 2                           ef    NA
# 3                           ta    NA
# 4                           ta    NA
# ...                        ...    ...
# 45932                      NaN   -
# 45933                      NaN   -
# 45934                      NaN   -
# 45935                      NaN   -
# 45936                      NaN   -
#
# [45937 rows x 21 columns]
