# %%
import pandas as pd
from datetime import datetime

# %%
df_ventas = pd.read_csv("tablas/ventas_df.csv", sep=";")
df_ventas.columns
# Out:
# /tmp/ipykernel_7383/3751433023.py:1: DtypeWarning: Columns (0: Nombre) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ventas = pd.read_csv("tablas/ventas_df.csv", sep=";")
# Index(['ID unico de factura', 'fecha', 'dia', 'mes', 'año', 'colegio',
#        'articulo', 'talla', 'hombro', 'talle', 'cintura', 'largo',
#        'ID unico de artículo', 'cantidad', 'precio individual', 'subtotal',
#        'Estado Factura', 'Producto pendiente por entregar',
#        'Clasificación_antiguo', 'Método de pago_antiguo', 'Nombre', 'día'],
#       dtype='str')

# %%
pd.set_option(
    "display.max_columns",
    None
)

print(df_ventas.tail(2))

df_ventas.tail(3)
# Out:
#                      ID unico de factura                           fecha  \
# 45994  20260609-225155-222-222-222-C-BGT      martes, 9 de junio de 2026
# 45995  20260610-193110-222-111-333-C-BGT  miércoles, 10 de junio de 2026
#
#         dia  mes   año             colegio  articulo talla  hombro  talle  \
# 45994   9.0    6  2026             conalco  pantalon     8     NaN    NaN
# 45995  10.0    6  2026  liceo pupo jimenez     blusa     2     NaN    NaN
#
#        cintura  largo        ID unico de artículo  cantidad precio individual  \
# 45994      NaN    NaN          conalco_pantalon_8         1           70000.0
# 45995      NaN    NaN  liceo pupo jimenez_blusa_2         1           37000.0
#
#       subtotal Estado Factura Producto pendiente por entregar  \
# 45994  70000.0      PENDIENTE                             NaN
# 45995  37000.0      PENDIENTE                             NaN
#
#       Clasificación_antiguo Método de pago_antiguo  Nombre
# 45994                   NaN                    NaN  test-2
# 45995                   NaN                    NaN  test 3
#                      ID unico de factura                           fecha  \
# 45993  20260609-225155-222-222-222-C-BGT      martes, 9 de junio de 2026
# 45994  20260609-225155-222-222-222-C-BGT      martes, 9 de junio de 2026
# 45995  20260610-193110-222-111-333-C-BGT  miércoles, 10 de junio de 2026
#
#         dia  mes   año               colegio  articulo talla  hombro  talle  \
# 45993   9.0    6  2026  gimnasio plaza feliz     blusa     8     NaN    NaN
# 45994   9.0    6  2026               conalco  pantalon     8     NaN    NaN
# 45995  10.0    6  2026    liceo pupo jimenez     blusa     2     NaN    NaN
#
#        cintura  largo          ID unico de artículo  cantidad  \
# 45993      NaN    NaN  gimnasio plaza feliz_blusa_8         1
# 45994      NaN    NaN            conalco_pantalon_8         1
# 45995      NaN    NaN    liceo pupo jimenez_blusa_2         1
#
#       precio individual subtotal Estado Factura  \
# 45993           41000.0  41000.0      PENDIENTE
# 45994           70000.0  70000.0      PENDIENTE
# 45995           37000.0  37000.0      PENDIENTE
#
#       Producto pendiente por entregar Clasificación_antiguo  \
# 45993                             NaN                   NaN
# 45994                             NaN                   NaN
# 45995                             NaN                   NaN
#
#       Método de pago_antiguo  Nombre
# 45993                    NaN  test-2
# 45994                    NaN  test-2
# 45995                    NaN  test 3

# %%
df_ventas = df_ventas.drop(
    columns=["día"],
    errors="ignore"
)
