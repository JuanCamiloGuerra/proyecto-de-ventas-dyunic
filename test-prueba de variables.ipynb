# %%
import pandas as pd
from datetime import datetime

# %%
df_ventas = pd.read_csv("tablas/ventas_df.csv", sep=";")
df_ventas.columns
# Out:
# /tmp/ipykernel_80021/3751433023.py:1: DtypeWarning: Columns (0: Nombre) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ventas = pd.read_csv("tablas/ventas_df.csv", sep=";")
# Index(['ID unico de factura', 'fecha', 'dia', 'mes', 'año', 'colegio',
#        'articulo', 'talla', 'hombro', 'talle', 'cintura', 'largo',
#        'ID unico de artículo', 'cantidad', 'precio individual', 'subtotal',
#        'Estado Factura', 'Producto pendiente por entregar',
#        'Clasificación_antiguo', 'Método de pago_antiguo', 'Nombre', 'día'],
#       dtype='str')

# %%
pd.set_option(
    "display.max_columns",
    None
)

print(df_ventas.tail(2))

df_precios.tail(3)
# Out:
#                           ID unico de factura                       fecha  \
# 45989  20260609-222515-9999-333333-1225-C-BGT  martes, 9 de junio de 2026
# 45990  20260609-222515-9999-333333-1225-C-BGT  martes, 9 de junio de 2026
#
#        dia  mes   año             colegio articulo talla  hombro  talle  \
# 45989  NaN    6  2026  liceo pupo jimenez    blusa     2     NaN    NaN
# 45990  NaN    6  2026  liceo pupo jimenez    blusa     4     NaN    NaN
#
#        cintura  largo        ID unico de artículo  cantidad precio individual  \
# 45989      NaN    NaN  liceo pupo jimenez_blusa_2         1           37000.0
# 45990      NaN    NaN  liceo pupo jimenez_blusa_4         1           37000.0
#
#       subtotal Estado Factura Producto pendiente por entregar  \
# 45989  37000.0         PAGADA                             NaN
# 45990  37000.0         PAGADA                             NaN
#
#       Clasificación_antiguo Método de pago_antiguo Nombre
# ...

# %%
df_ventas = df_ventas.drop(
    columns=["día"],
    errors="ignore"
)
