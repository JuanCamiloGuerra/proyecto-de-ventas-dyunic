# %%
import streamlit as st
import pandas as pd
from datetime import datetime

# %%
df_precios = pd.read_csv("tablas/precios.csv", sep=";")
df_precios.columns
# Out:
# Index(['colegio', 'PRODUCTO', 'TALLA', 'VALOR AÑO PRESENTE', 'ID_BUSQUEDA',
#        '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029'],
#       dtype='str')
